# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from census import Census
from us import states
import functions

# %%
master_df = pd.read_csv('resources/MasterData200730.csv')
master_df = master_df.drop(columns="Unnamed: 0")

# %%
master_df.head()
# Out:
#         State Abv                 Date     Tested  Positive  Deaths  \
# 0      Alaska  AK  2020-07-25 07:10:21   200572.0    1693.0    19.0
# 1     Alabama  AL  2020-07-25 07:10:21   627344.0   74365.0  1395.0
# 2    Arkansas  AR  2020-07-22 05:16:54   439635.0   34655.0   374.0
# 3     Arizona  AZ  2020-07-25 07:23:41  1053832.0  156301.0  3142.0
# 4  California  CA  2020-07-25 07:23:41  6915876.0  435334.0  8186.0
#
#    Mortality Rate  Happiness Rank  totalScore  Emotional/Physical Rank  \
# 0        1.122268              47       38.21                       33
# 1        1.875882              45       39.35                       46
# 2        1.079209              49       36.61                       50
# 3        2.010224              21       52.92                       27
# 4        1.880395               5       63.14                        4
#
#    Work Enviroment Rank  Community Enviroment Rank  Happiness Rank Inv  \
# 0                    49                         50                   3
# 1                    39                         43                   5
# 2                    29                         23                   1
# 3                    12                         34                  29
# 4                    24                         12                  45
#
#    Emotional/Physical Rank Inv  Work Enviroment Rank Inv  \
# 0                           17                         1
# 1                            4                        11
# 2                            0                        21
# 3                           23                        38
# 4                           46                        26
#
#    Community Enviroment Rank Inv
# 0                              0
# 1                              7
# 2                             27
# 3                             16
# 4                             38

# %%
# Scatter Plot
# Make xtick labels = State names
# Increase figure size
plt.figure(figsize=(14, 10))
plt.scatter( master_df["Happiness Rank"], 
            master_df["Mortality Rate"], 
            c="purple"
           )
plt.xticks(ticks=master_df["Happiness Rank Inv"], labels=master_df["State"], rotation=45)
plt.show()

# %%
master_df = master_df.set_index('State')
master_df['State Population'] = ''

# %%
master_df.head()
# Out:
#            Abv                 Date     Tested  Positive  Deaths  \
# State
# Alaska      AK  2020-07-25 07:10:21   200572.0    1693.0    19.0
# Alabama     AL  2020-07-25 07:10:21   627344.0   74365.0  1395.0
# Arkansas    AR  2020-07-22 05:16:54   439635.0   34655.0   374.0
# Arizona     AZ  2020-07-25 07:23:41  1053832.0  156301.0  3142.0
# California  CA  2020-07-25 07:23:41  6915876.0  435334.0  8186.0
#
#             Mortality Rate  Happiness Rank  totalScore  \
# State
# Alaska            1.122268              47       38.21
# Alabama           1.875882              45       39.35
# Arkansas          1.079209              49       36.61
# Arizona           2.010224              21       52.92
# California        1.880395               5       63.14
#
#             Emotional/Physical Rank  Work Enviroment Rank  \
# State
# Alaska                           33                    49
# Alabama                          46                    39
# Arkansas                         50                    29
# Arizona                          27                    12
# California                        4                    24
#
#             Community Enviroment Rank  Happiness Rank Inv  \
# State
# Alaska                             50                   3
# Alabama                            43                   5
# Arkansas                           23                   1
# Arizona                            34                  29
# California                         12                  45
#
#             Emotional/Physical Rank Inv  Work Enviroment Rank Inv  \
# State
# Alaska                               17                         1
# Alabama                               4                        11
# Arkansas                              0                        21
# Arizona                              23                        38
# California                           46                        26
#
#             Community Enviroment Rank Inv State Population
# State
# Alaska                                  0                0
# Alabama                                 7
# Arkansas                               27
# Arizona                                16
# California                             38

# %%
c = Census("661e1f2142e1cf49fc3ccb14fbef9446886ea826")
state_pop_data = c.acs5.get(('NAME', 'B01003_001E'), {'for': 'state:*'})
print(state_pop_data)

for item in state_pop_data:
    pop = item['B01003_001E']
    name = item['NAME']
    master_df.loc[name, "State Population"] = pop

master_df.head(10)
# Out:
#             Abv                 Date     Tested  Positive  Deaths  \
# State
# Alaska       AK  2020-07-25 07:10:21   200572.0    1693.0    19.0
# Alabama      AL  2020-07-25 07:10:21   627344.0   74365.0  1395.0
# Arkansas     AR  2020-07-22 05:16:54   439635.0   34655.0   374.0
# Arizona      AZ  2020-07-25 07:23:41  1053832.0  156301.0  3142.0
# California   CA  2020-07-25 07:23:41  6915876.0  435334.0  8186.0
# Colorado     CO  2020-07-25 07:10:21   476586.0   42980.0  1598.0
# Connecticut  CT  2020-07-22 05:16:54   660857.0   48096.0  4406.0
# Delaware     DE  2020-07-22 05:16:54   158347.0   13746.0   525.0
# Florida      FL  2020-07-25 07:23:41  3276636.0  402312.0  5653.0
# Georgia      GA  2020-07-25 07:23:41  1382444.0  161401.0  3442.0
#
#              Mortality Rate  Happiness Rank  totalScore  \
# State
# Alaska             1.122268            47.0       38.21
# Alabama            1.875882            45.0       39.35
# Arkansas           1.079209            49.0       36.61
# Arizona            2.010224            21.0       52.92
# California         1.880395             5.0       63.14
# Colorado           3.718008            18.0       55.38
# Connecticut        9.160845            12.0       58.24
# Delaware           3.819293            27.0       51.67
# Florida            1.405128            29.0       51.01
# Georgia            2.132577            19.0       55.15
#
#              Emotional/Physical Rank  Work Enviroment Rank  \
# State
# Alaska                          33.0                  49.0
# Alabama                         46.0                  39.0
# Arkansas                        50.0                  29.0
# Arizona                         27.0                  12.0
# California                       4.0                  24.0
# Colorado                        19.0                   3.0
# Connecticut                      9.0                  40.0
# Delaware                        17.0                  37.0
# Florida                         20.0                  20.0
# Georgia                         25.0                  16.0
#
#              Community Enviroment Rank  Happiness Rank Inv  \
# State
# Alaska                            50.0                 3.0
# Alabama                           43.0                 5.0
# Arkansas                          23.0                 1.0
# Arizona                           34.0                29.0
# California                        12.0                45.0
# Colorado                          46.0                32.0
# Connecticut                       18.0                38.0
# Delaware                          45.0                23.0
# Florida                           47.0                21.0
# Georgia                            7.0                31.0
#
#              Emotional/Physical Rank Inv  Work Enviroment Rank Inv  \
# State
# Alaska                              17.0                       1.0
# Alabama                              4.0                      11.0
# Arkansas                             0.0                      21.0
# Arizona                             23.0                      38.0
# California                          46.0                      26.0
# Colorado                            31.0                      47.0
# Connecticut                         41.0                      10.0
# Delaware                            33.0                      13.0
# Florida                             30.0                      30.0
# Georgia                             25.0                      34.0
#
#              Community Enviroment Rank Inv State Population
# State
# Alaska                                 0.0           738516
# Alabama                                7.0      4.86468e+06
# Arkansas                              27.0      2.99067e+06
# Arizona                               16.0      6.94668e+06
# California                            38.0      3.91488e+07
# Colorado                               4.0      5.53114e+06
# Connecticut                           32.0       3.5815e+06
# Delaware                               5.0           949495
# Florida                                3.0      2.05981e+07
# Georgia                               43.0      1.02975e+07

# %%
master_df.to_csv('Resources/MasterData200730.csv')

# %%
deaths_per_pop = master_df["Deaths"] / master_df["State Population"].astype('float64') * 1000000
deaths_per_pop = deaths_per_pop.dropna()
master_df = master_df.dropna()

# %%
plt.figure(figsize=(15, 11))
slope, intercept, r_value, p_value, std_err = linregress(master_df["Happiness Rank Inv"], deaths_per_pop)
print("R-squared: %f" % r_value**2)
plt.scatter( master_df["Happiness Rank Inv"], 
             deaths_per_pop, 
             c="blue"
           )
plt.show()
# Out:
# R-squared: 0.022397
